# %% [markdown]
# <a href="https://colab.research.google.com/github/Melvinmcrn/DataScience/blob/master/Assignment1_GetInsight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sb

# %%
data = pd.read_excel('https://github.com/Melvinmcrn/DataScience/blob/master/Data_Science_Course_2020_(Survey_DataSet).xlsx?raw=true')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 23 columns):
# ID                                                                                                                                      51 non-null int64
# Year                                                                                                                                    51 non-null int64
# Department (e.g. Computer Engineering)                                                                                                  51 non-null object
# Gender                                                                                                                                  51 non-null object
# Grade (GPAX)                                                                                                                            51 non-null object
# ...

# %%
data.head()
# Out:
#    ID  ...  Have you ever taken class of Aj.Andrew Ng or online course about Machine Learning, Deep Learning, NLP or something like this before?
# 0   1  ...                                                Yes
# 1   2  ...                                                 No
# 2   3  ...                                                 No
# 3   4  ...                                                 No
# 4   5  ...                                                 No
#
# [5 rows x 23 columns]

# %%
sb.set(style='darkgrid')
sb.countplot(x='Year', data=data)

# %% [markdown]
# mostly 4th year student.

# %%
sb.set(style='darkgrid')
sb.countplot(x='Department (e.g. Computer Engineering)', data=data)

# %% [markdown]
# Every student is a Computer Engineering Student (Why type in different word lol)

# %%
sb.set(style='darkgrid')
sb.countplot(x='Grade (GPAX)', data=data)

# %% [markdown]
# most students have good grade so they mostly come for knowledge more that good grade.

# %%
sb.set(style='darkgrid')
sb.countplot(x='Have you ever did "Data Science" before?', data=data)

# %% [markdown]
# mostly never did 'Data Science' so instructor might need to teach from the basic and might not be able to go too fast because students might not be able to catch up.

# %%
sb.set(style='darkgrid')
sb.countplot(x='Have you ever used "Web Scraping” before?', data=data)

# %% [markdown]
# Almost everyone never use 'Web Scraping' so maybe this method need to be taught from the beginning.

# %%
sb.set(style='darkgrid')
sb.countplot(x='Have you ever did "Machine Learning" before?', data=data)

# %% [markdown]
# About half of the students have already did 'Machine Learning' so the content in the Machine Learning part doesn't need to be taught so much.

# %%
sb.set(style='darkgrid')
sb.countplot(x='Have you ever did "Business Intelligence (BI)" before?', data=data)

# %% [markdown]
# Almost every students never did BI (personally, I don't even know what it is) so if it is essential, maybe we need to learn from the beginning.

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Python skill?', data=data)

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Pandas skill?', data=data)

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Scikit-learn skill?', data=data)

# %% [markdown]
# Almost everyone has an intermediate skills in Python so coding in Python is ok with everyone. Instructor might need to teach the logic of the Data Science and the students might be able to adapt to code. But instructors might need to show more examples and ability of pandas and scikit because students are mostly beginner.

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Power BI skill?', data=data)

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Tableau skill?', data=data)

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of BeautifulSoup skill?', data=data)

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Spark skill?', data=data)

# %% [markdown]
# I (and most students) never use Power BI, Tableau, BeautifulSoup or Spark (actually I prefer a choice 'NONE' because this is what I will choose). Instructor might need to tell the ability and some example of it.

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of SQL skill?', data=data)

# %% [markdown]
# most students has skills in SQL (because we all learned them in Database Design) so maybe we don't need to learn much in this part.

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Hypothesis Test (including Statistical) skill?', data=data)

# %% [markdown]
# Maybe we need to learn more about this.

# %%
sb.set(style='darkgrid')
sb.countplot(x='What is your level of Linux skill?', data=data)

# %% [markdown]
# About half of the students have intermediate skill in linux (I don't understand much about how is this involve with Data Science). So maybe if instructors wanted to use cloud computer running Linux, it's ok with most students.

# %% [markdown]
# # Conslusion

# %% [markdown]
# We can use cloud computer to train or compile our model because most of us can use Linux.
#
# What need to be taught more in this course:<br>
# -Web Scraping<br>
# -BI<br>
# -Power BI<br>
# -Tableau<br>
# -BeautifulSoup<br>
# -Spark<br>
# -Hypothesis Test<br>
#
# What doesn't need to be taught much:<br>
# -Machine Learning<br>
# -Python<br>
# -SQL<br>
